# %% [markdown]
# <a href="https://colab.research.google.com/github/shail1811/DL/blob/master/Mnist_FeedForward.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras import datasets , layers , models
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical

# %%
(train_images , train_labels) , (test_images , test_labels) = datasets.mnist.load_data()
train_images , test_images = train_images / 255.0 , test_images / 255.0
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
train_images = train_images.reshape(train_images.shape[0],28,28,1)
test_images = test_images.reshape(test_images.shape[0],28,28,1)
print(train_images.shape)
print(test_images.shape)
print(train_labels.shape)
print(test_labels.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)
# (60000, 10)
# (10000, 10)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD , Adam

model = models.Sequential()

model.add(layers.Flatten(input_shape = (28,28,1)))
model.add(Dense(64,activation = 'relu'))
model.add(Dense(10, activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_11 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dense_21 (Dense)             (None, 10)                650
# ...
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(Adam(lr=0.01),'mean_squared_error' ,metrics=['accuracy'])
model.fit(train_images , train_labels , epochs = 100 )
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0088 - accuracy: 0.9558
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0092 - accuracy: 0.9539
# Epoch 3/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0106 - accuracy: 0.9469
# Epoch 4/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0104 - accuracy: 0.9479
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0098 - accuracy: 0.9510
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0091 - accuracy: 0.9542
# Epoch 7/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0098 - accuracy: 0.9509
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0088 - accuracy: 0.9559
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0092 - accuracy: 0.9537
# Epoch 10/100
# ...

# %%
model.compile(Adam(lr=0.01),'categorical_crossentropy' ,metrics=['accuracy'])
model.fit(train_images , train_labels , epochs = 100 )
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 15.6039 - accuracy: 0.9689
# Epoch 2/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 7.6002 - accuracy: 0.9666
# Epoch 3/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 4.5350 - accuracy: 0.9629
# Epoch 4/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.7346 - accuracy: 0.9501
# Epoch 5/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.4841 - accuracy: 0.9312
# Epoch 6/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.8541 - accuracy: 0.9011
# Epoch 7/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6193 - accuracy: 0.8978
# Epoch 8/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4925 - accuracy: 0.9093
# Epoch 9/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4232 - accuracy: 0.9126
# Epoch 10/100
# ...

# %%
model.compile(SGD(lr=0.01),'categorical_crossentropy' ,metrics=['accuracy'])
model.fit(train_images , train_labels , epochs = 100 )
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1114 - accuracy: 0.9797
# Epoch 2/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0895 - accuracy: 0.9807
# Epoch 3/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0793 - accuracy: 0.9811
# Epoch 4/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0733 - accuracy: 0.9813
# Epoch 5/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0690 - accuracy: 0.9818
# Epoch 6/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0659 - accuracy: 0.9822
# Epoch 7/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0637 - accuracy: 0.9821
# Epoch 8/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0620 - accuracy: 0.9823
# Epoch 9/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0606 - accuracy: 0.9823
# Epoch 10/100
# ...

# %%
model.compile(SGD(lr=0.01),'mean_squared_error' ,metrics=['accuracy'])
model.fit(train_images , train_labels , epochs = 100 )
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0021 - accuracy: 0.9843
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0021 - accuracy: 0.9843
# Epoch 3/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0021 - accuracy: 0.9844
# Epoch 4/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0021 - accuracy: 0.9844
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0021 - accuracy: 0.9844
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0021 - accuracy: 0.9844
# Epoch 7/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0021 - accuracy: 0.9844
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0021 - accuracy: 0.9844
# Epoch 9/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0021 - accuracy: 0.9844
# Epoch 10/100
# ...
